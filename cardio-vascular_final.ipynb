# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading up Dataset

# %%
df = pd.read_csv("C:/Users/Habeeb/Downloads/cardio_train.csv/cardio_train.csv")
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# Converting the atrribue Age from days to years

# %%
df["age"] = df["age"].apply(lambda x: x/365).astype("int")
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2     168    62.0    110     80            1     1
# 1          1   55       1     156    85.0    140     90            3     1
# 2          2   51       1     165    64.0    130     70            3     1
# 3          3   48       2     169    82.0    150    100            1     1
# 4          4   47       1     156    56.0    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   52       2     168    76.0    120     80            1     1
# 69996  99995   61       1     158   126.0    140     90            2     2
# 69997  99996   52       2     183   105.0    180     90            3     1
# 69998  99998   61       1     163    72.0    135     80            1     2
# 69999  99999   56       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# Converting the attribute height from centimeters to meters

# %%
df["height"] = df["height"].apply(lambda x: x/100)

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2    1.68    62.0    110     80            1     1
# 1          1   55       1    1.56    85.0    140     90            3     1
# 2          2   51       1    1.65    64.0    130     70            3     1
# 3          3   48       2    1.69    82.0    150    100            1     1
# 4          4   47       1    1.56    56.0    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   52       2    1.68    76.0    120     80            1     1
# 69996  99995   61       1    1.58   126.0    140     90            2     2
# 69997  99996   52       2    1.83   105.0    180     90            3     1
# 69998  99998   61       1    1.63    72.0    135     80            1     2
# 69999  99999   56       1    1.70    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2    1.68    62.0    110     80            1     1      0
# 1   1   55       1    1.56    85.0    140     90            3     1      0
# 2   2   51       1    1.65    64.0    130     70            3     1      0
# 3   3   48       2    1.69    82.0    150    100            1     1      0
# 4   4   47       1    1.56    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.tail()
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993   52       2    1.68    76.0    120     80            1     1
# 69996  99995   61       1    1.58   126.0    140     90            2     2
# 69997  99996   52       2    1.83   105.0    180     90            3     1
# 69998  99998   61       1    1.63    72.0    135     80            1     2
# 69999  99999   56       1    1.70    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int32
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  float64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(2), int32(1), int64(10)
# memory usage: 6.7 MB

# %%
df.shape
# Out:
# (70000, 13)

# %% [markdown]
# This dataset contains 7000 inputs and 13 features

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# This dataset does not contain any missing/null values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# This dataset does not contain any duplicated values

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900     52.840671      1.349571      1.643592     74.205690
# std    28851.302323      6.766774      0.476838      0.082101     14.395757
# min        0.000000     29.000000      1.000000      0.550000     10.000000
# 25%    25006.750000     48.000000      1.000000      1.590000     65.000000
# 50%    50001.500000     53.000000      1.000000      1.650000     72.000000
# 75%    74889.250000     58.000000      2.000000      1.700000     82.000000
# max    99999.000000     64.000000      2.000000      2.500000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %% [markdown]
# 1. Count
# All columns have 70,000 rows (no missing data reported here).
#
# 2. Mean
# age: Average age is ~52.8 years.
#
# gender: Mean is 1.35 (values 1 or 2, likely 1=male, 2=female; slightly more males if 1=male).
#
# height: Mean ~1.64 meters (164 cm), typical adult height.
#
# weight: Mean ~74.2 kg.
#
# ap_hi (systolic blood pressure): Mean 128.8 mmHg (slightly elevated; normal <120).
#
# ap_lo (diastolic blood pressure): Mean 96.6 mmHg (elevated; normal <80).
#
# cholesterol: Mean 1.37 (categories 1, 2, 3).
#
# gluc (glucose): Mean 1.23 (categories 1, 2, 3).
#
# smoke: Mean 0.088 (about 8.8% are smokers).
#
# alco (alcohol): Mean 0.054 (about 5.4% consume alcohol).
#
# active: Mean 0.80 (about 80% physically active).
#
# cardio: Mean 0.50 (balanced classes — about half have cardiovascular disease).
#
# 3. Std (Standard Deviation)
# Age: 6.77 years — relatively tight spread around mean.
#
# Height: 0.082 meters (~8 cm) variation.
#
# Weight: 14.4 kg variation.
#
# ap_hi: 154 mmHg — very high variability, suspicious.
#
# ap_lo: 188 mmHg — even higher variability, suspicious.
#
# cholesterol & gluc: Std dev around 0.68 and 0.57 — moderate variation.
#
# smoke & alco: Low std dev since these are binary flags.
#
# active: 0.40 — moderate variation.
#
# cardio: 0.50 — balanced binary.
#
# 4. Min and Max (Important Observations)
# ap_hi (systolic BP): Min = -150, Max = 200 — Negative blood pressure is impossible, so this shows data errors or outliers.
#
# ap_lo (diastolic BP): Min = -70, Max = 11000 — Clearly invalid (diastolic usually max ~120). This is a red flag indicating erroneous data.
#
# weight: Min = 10 kg (possible for infants?), Max = 250 kg (very high but plausible).
#
# height: Min = 0.55 m (very short, possible child?), Max = 2.5 m (improbably tall, likely error).
#
# cholesterol & gluc: min=1, max=3 (categorical variables).
#
# gender: min=1, max=2, so coding is consistent.
#
# smoke, alco, active, cardio: binary 0 or 1 as expected.
#
# 5. Percentiles
# Median age is 53 (50th percentile).
#
# Median ap_hi = 72 (but mean is 128.8 — suggests some extreme values skewing the mean).
#
# Median ap_lo = 120 (again, differs drastically from mean 96.6 and max/min extremes).
#
# 75th percentile cholesterol = 2, gluc = 1 (most people have normal glucose and cholesterol).
#
# 75th percentile for active = 1 (most people physically active).
#
# Summary and Key Takeaways
# Data Quality Issues: The extreme and negative values in ap_hi and ap_lo (blood pressure) columns are suspicious and indicate data entry or measurement errors. These should be cleaned or treated before modeling.
#
# Balanced Target: The cardio variable is about half 0 and half 1 — good for balanced classification.
#
# Categorical variables: Cholesterol and glucose are categorical with 3 levels.
#
# Low prevalence of smoking and alcohol consumption in this dataset.
#
# Physical activity is high (~80%).
#
# Age distribution centers around early 50s.

# %%
df.nunique()
# Out:
# id             70000
# age               28
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64

# %% [markdown]
# id: 70,000 unique IDs (one per row)
#
# age: 28 unique ages (likely in years)
#
# gender: 2 values (1 = Male, 2 = Female)
#
# height: 109 values (in cm)
#
# weight: 287 values (in kg)
#
# ap_hi: 153 values (Systolic blood pressure)
#
# ap_lo: 157 values (Diastolic blood pressure)
#
# cholesterol: 3 levels (1 = Normal, 2 = Above normal, 3 = Well above normal)
#
# gluc: 3 levels (same as cholesterol)
#
# smoke: 2 values (likely 0 = No, 1 = Yes)
#
# alco: 2 values (likely 0 = No, 1 = Yes)
#
# active: 2 values (likely 0 = No, 1 = Yes)
#
# cardio: 2 values (0 = No cardiovascular disease, 1 = Yes)

# %%
# Define mapping dictionaries using your provided definitions
label_maps = {
    "gender": {1: "Female", 2: "Male"},
    "cholesterol": {1: "Normal", 2: "Above Normal", 3: "Well Above Normal"},
    "gluc": {1: "Normal", 2: "Above Normal", 3: "Well Above Normal"},
    "smoke": {0: "No", 1: "Yes"},
    "alco": {0: "No", 1: "Yes"},
    "active": {0: "No", 1: "Yes"},
    "cardio": {0: "No", 1: "Yes"}
}

# List of columns to map
cat_col = ["gender", "cholesterol", "gluc", "smoke", "alco", "active", "cardio"]

# Print value counts using the mappings
for column in cat_col:
    print(f"--- {column.upper()} ---")
    print(df[column].map(label_maps[column]).value_counts())
    print("-" * 40)
# Out:
# --- GENDER ---
# gender
# Female    45530
# Male      24470
# Name: count, dtype: int64
# ----------------------------------------
# --- CHOLESTEROL ---
# cholesterol
# Normal               52385
# Above Normal          9549
# Well Above Normal     8066
# Name: count, dtype: int64
# ----------------------------------------
# --- GLUC ---
# gluc
# Normal               59479
# Well Above Normal     5331
# Above Normal          5190
# Name: count, dtype: int64
# ----------------------------------------
# --- SMOKE ---
# smoke
# No     63831
# Yes     6169
# Name: count, dtype: int64
# ----------------------------------------
# --- ALCO ---
# alco
# No     66236
# Yes     3764
# Name: count, dtype: int64
# ----------------------------------------
# --- ACTIVE ---
# active
# Yes    56261
# No     13739
# Name: count, dtype: int64
# ----------------------------------------
# --- CARDIO ---
# cardio
# No     35021
# Yes    34979
# Name: count, dtype: int64
# ...

# %%
# Define mapping dictionaries for the selected columns
label_maps = {
    "alco": {0: "No", 1: "Yes"},
    "active": {0: "No", 1: "Yes"},
    "cardio": {0: "No", 1: "Yes"}
}

cat_col = ["alco", "active", "cardio"]

# Print value counts using the mappings
for column in cat_col:
    print(f"--- {column.upper()} ---")
    print(df[column].map(label_maps[column]).value_counts())
    print("-" * 40)
# Out:
# --- ALCO ---
# alco
# No     66236
# Yes     3764
# Name: count, dtype: int64
# ----------------------------------------
# --- ACTIVE ---
# active
# Yes    56261
# No     13739
# Name: count, dtype: int64
# ----------------------------------------
# --- CARDIO ---
# cardio
# No     35021
# Yes    34979
# Name: count, dtype: int64
# ----------------------------------------

# %%
# function to create labeled barplots


def labeled_barplot(df, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(df[feature])  # length of the column
    count = df[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=df,
        x=feature,
        palette="Paired",
        order=df[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
labeled_barplot(df, "gender", perc=True)

# %%
def labeled_barplot(df, feature, perc=False, n=None, label_map=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    label_map: dict mapping original feature values to display names (default is None)
    """

    # If label_map is provided, create a copy and map the feature column
    if label_map is not None:
        df = df.copy()
        df[feature] = df[feature].map(label_map)

    total = len(df[feature])  # length of the column
    count = df[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=df,
        x=feature,
        palette="Paired",
        order=df[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc:
            label = "{:.1f}%".format(100 * p.get_height() / total)  # percentage of each class
        else:
            label = p.get_height()  # count of each level

        x = p.get_x() + p.get_width() / 2  # center of the bar
        y = p.get_height()

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )

    plt.show()

# %%
gender_map = {1: "Female", 2: "Male"}
labeled_barplot(df, "gender", perc=True, label_map=gender_map)

# %% [markdown]
# 65% of the gender in the dataset are women while 35% are men

# %%
# Group by gender and cardio, then count
grouped = df.groupby("gender")["cardio"].value_counts()

# Convert to DataFrame
grouped_df = grouped.rename('count').reset_index()

# Map numeric values to labels
grouped_df['cardio'] = grouped_df['cardio'].map({0: 'No', 1: 'Yes'})
grouped_df['gender'] = grouped_df['gender'].map({1: 'Female', 2: 'Male'})

print(grouped_df)
# Out:
#    gender cardio  count
# 0  Female     No  22914
# 1  Female    Yes  22616
# 2    Male    Yes  12363
# 3    Male     No  12107

# %%
# Group by gender, smoke, and cardio and count occurrences
grouped = df.groupby("gender")[["smoke", "cardio"]].apply(lambda x: x.value_counts()).reset_index(name='count')

# Map numeric to labels for gender, smoke, and cardio
grouped['gender'] = grouped['gender'].map({1: 'Female', 2: 'Male'})
grouped['smoke'] = grouped['smoke'].map({0: 'No', 1: 'Yes'})
grouped['cardio'] = grouped['cardio'].map({0: 'No', 1: 'Yes'})

print(grouped)
# Out:
#    gender smoke cardio  count
# 0  Female    No     No  22489
# 1  Female    No    Yes  22228
# 2  Female   Yes     No    425
# 3  Female   Yes    Yes    388
# 4    Male    No    Yes   9822
# 5    Male    No     No   9292
# 6    Male   Yes     No   2815
# 7    Male   Yes    Yes   2541

# %%
# Step 1: Group and count
grouped = df.groupby("gender")[["smoke", "cardio"]].value_counts().reset_index(name='count')

# Step 2: Map numeric values to labels
grouped['gender'] = grouped['gender'].map({1: 'Female', 2: 'Male'})
grouped['smoke'] = grouped['smoke'].map({0: 'No', 1: 'Yes'})
grouped['cardio'] = grouped['cardio'].map({0: 'No', 1: 'Yes'})

# Step 3: Plot - one chart per gender
g = sns.catplot(
    data=grouped,
    x='smoke',
    y='count',
    hue='cardio',
    col='gender',
    kind='bar',
    height=5,
    aspect=1
)

# Customize plot
g.set_axis_labels("Smoking Status", "Count")
g.set_titles("Gender: {col_name}")
g._legend.set_title("Cardiovascular Disease")
g.fig.suptitle("Smoking vs Cardiovascular Disease by Gender", y=1.05)

plt.show()

# %% [markdown]
# Females (Gender 1): Most are non-smokers. Cardio cases are nearly equal between non-smokers and slightly fewer among smokers.
#
# Males (Gender 2): More smokers than females. Cardio cases are slightly higher among non-smokers. Fewer cardio cases among smokers.
# Overall: Non-smokers dominate. Cardio cases appear more frequent in non-smokers, suggesting other factors may influence the outcome.

# %%
# Group and count
grouped = df.groupby("gender")[["active", "cardio"]].value_counts().reset_index(name='count')

# Map numeric codes to descriptive labels
grouped['gender'] = grouped['gender'].map({1: 'Female', 2: 'Male'})
grouped['active'] = grouped['active'].map({0: 'No', 1: 'Yes'})
grouped['cardio'] = grouped['cardio'].map({0: 'No', 1: 'Yes'})

print(grouped)
# Out:
#    gender active cardio  count
# 0  Female    Yes     No  18649
# 1  Female    Yes    Yes  17867
# 2  Female     No    Yes   4749
# 3  Female     No     No   4265
# 4    Male    Yes     No   9994
# 5    Male    Yes    Yes   9751
# 6    Male     No    Yes   2612
# 7    Male     No     No   2113

# %%
# Group and count
grouped = df.groupby("gender")[["active", "cardio"]].value_counts().reset_index(name='count')

# Map numeric codes to descriptive labels
grouped['gender'] = grouped['gender'].map({1: 'Female', 2: 'Male'})
grouped['active'] = grouped['active'].map({0: 'No', 1: 'Yes'})
grouped['cardio'] = grouped['cardio'].map({0: 'No', 1: 'Yes'})

# Convert to string (optional but helpful for plotting)
grouped['gender'] = grouped['gender'].astype(str)
grouped['active'] = grouped['active'].astype(str)
grouped['cardio'] = grouped['cardio'].astype(str)

# Create the barplot (faceted by gender)
g = sns.catplot(
    data=grouped,
    x='active',
    y='count',
    hue='cardio',
    col='gender',
    kind='bar',
    height=5,
    aspect=1
)

# Customize the plot
g.set_axis_labels("Physical Activity", "Count")
g.set_titles("Gender: {col_name}")
g._legend.set_title("Cardio")
g.fig.suptitle("Physical Activity vs Cardio by Gender", y=1.05)

plt.show()

# %% [markdown]
# Females (Gender 1): Most are physically active. Cardio cases are slightly higher among the inactive group.
#
# Males (Gender 2): Similar pattern—majority are active, but inactive males show a higher proportion of cardio cases.
# Overall: Lack of physical activity is associated with a higher count of cardio cases for both genders.

# %%
# Step 1: Group and count
grouped = df.groupby("gender")[["alco", "cardio"]].value_counts().reset_index(name='count')

# Step 2: Map numeric values to real labels
grouped["gender"] = grouped["gender"].map({1: "Female", 2: "Male"})
grouped["alco"] = grouped["alco"].map({0: "No", 1: "Yes"})
grouped["cardio"] = grouped["cardio"].map({0: "No", 1: "Yes"})

# Step 3: Display
print(grouped)
# Out:
#    gender alco cardio  count
# 0  Female   No     No  22332
# 1  Female   No    Yes  22037
# 2  Female  Yes     No    582
# 3  Female  Yes    Yes    579
# 4    Male   No    Yes  11119
# 5    Male   No     No  10748
# 6    Male  Yes     No   1359
# 7    Male  Yes    Yes   1244

# %%
# Step 1: Group and count
grouped = df.groupby("gender")[["alco", "cardio"]].value_counts().reset_index(name='count')

# Step 2: Map numerical values to real-world labels
grouped['gender'] = grouped['gender'].map({1: "Female", 2: "Male"})
grouped['alco'] = grouped['alco'].map({0: "No", 1: "Yes"})
grouped['cardio'] = grouped['cardio'].map({0: "No", 1: "Yes"})

# Step 3: Plot using Seaborn's FacetGrid
g = sns.catplot(
    data=grouped,
    x='alco',
    y='count',
    hue='cardio',
    col='gender',
    kind='bar',
    height=5,
    aspect=1
)

# Step 4: Customize plot
g.set_axis_labels("Alcohol Consumption", "Count")
g.set_titles("Gender: {col_name}")
g._legend.set_title("Cardiovascular Disease")
g.fig.suptitle("Alcohol Consumption vs Cardiovascular Disease by Gender", y=1.05)

# Show plot
plt.show()

# %% [markdown]
# Females (Gender 1): Majority do not consume alcohol. Cardio cases are similar regardless of alcohol consumption.
#
# Males (Gender 2): Non-drinkers have more cardio cases than drinkers.
# Overall: Alcohol consumption shows minimal impact on cardio cases across both genders.

# %%
# Group and count
grouped = df.groupby("gender")[["gluc", "cardio"]].value_counts().reset_index(name='count')

# Map values to readable labels
grouped['gender'] = grouped['gender'].map({1: "Female", 2: "Male"})
grouped['gluc'] = grouped['gluc'].map({1: "Normal", 2: "Above Normal", 3: "Well Above Normal"})
grouped['cardio'] = grouped['cardio'].map({0: "No", 1: "Yes"})

# Display result
print(grouped)
# Out:
#     gender               gluc cardio  count
# 0   Female             Normal     No  20159
# 1   Female             Normal    Yes  18312
# 2   Female  Well Above Normal    Yes   2319
# 3   Female       Above Normal    Yes   1985
# 4   Female       Above Normal     No   1431
# 5   Female  Well Above Normal     No   1324
# 6     Male             Normal     No  10735
# 7     Male             Normal    Yes  10273
# 8     Male       Above Normal    Yes   1093
# 9     Male  Well Above Normal    Yes    997
# 10    Male  Well Above Normal     No    691
# 11    Male       Above Normal     No    681

# %%
# Group and count
grouped = df.groupby("gender")[["gluc", "cardio"]].value_counts().reset_index(name='count')

# Step 2: Map numerical codes to readable labels
grouped['gender'] = grouped['gender'].map({1: "Female", 2: "Male"})
grouped['gluc'] = grouped['gluc'].map({
    1: "Normal", 
    2: "Above Normal", 
    3: "Well Above Normal"
})
grouped['cardio'] = grouped['cardio'].map({0: "No", 1: "Yes"})

# Step 3: Visualize with Seaborn
g = sns.catplot(
    data=grouped,
    x='gluc',
    y='count',
    hue='cardio',
    col='gender',
    kind='bar',
    height=5,
    aspect=1
)

# Step 4: Customize plot
g.set_axis_labels("Glucose Level", "Count")
g.set_titles("Gender: {col_name}")
g._legend.set_title("Cardio")
g.fig.suptitle("Glucose Level vs Cardio by Gender", y=1.05)

plt.show()

# %% [markdown]
# Females (Gender: 1)
# Normal Glucose (1): Majority have normal levels, with cardio cases slightly lower than non-cases.
# Above/Well Above Normal (2, 3): Cardio cases exceed non-cases—suggesting higher glucose may be linked to increased cardio risk.
#
# Males (Gender: 2)
# Normal Glucose (1): Cardio and non-cardio cases are close in number.
# Above/Well Above Normal (2, 3): Similar to females, cardio cases are higher, especially at glucose level 3.
#
# Insight:
# Elevated glucose levels (2 & 3) correlate with higher cardio disease prevalence in both males and females. This implies glucose is a strong indicator for cardiovascular risk.

# %%
# Step 1: Group and count
grouped = df.groupby("gender")[["gluc", "cardio"]].value_counts().reset_index(name='count')

# Step 2: Map numeric values to meaningful labels
grouped['gender'] = grouped['gender'].map({1: 'Female', 2: 'Male'})
grouped['gluc'] = grouped['gluc'].map({
    1: 'Normal',
    2: 'Above Normal',
    3: 'Well Above Normal'
})
grouped['cardio'] = grouped['cardio'].map({0: 'No', 1: 'Yes'})

# Step 3: Display the mapped DataFrame
print(grouped)
# Out:
#     gender               gluc cardio  count
# 0   Female             Normal     No  20159
# 1   Female             Normal    Yes  18312
# 2   Female  Well Above Normal    Yes   2319
# 3   Female       Above Normal    Yes   1985
# 4   Female       Above Normal     No   1431
# 5   Female  Well Above Normal     No   1324
# 6     Male             Normal     No  10735
# 7     Male             Normal    Yes  10273
# 8     Male       Above Normal    Yes   1093
# 9     Male  Well Above Normal    Yes    997
# 10    Male  Well Above Normal     No    691
# 11    Male       Above Normal     No    681

# %%
# Step 1: Group and count
grouped = df.groupby("gender")[["cholesterol", "cardio"]].value_counts().reset_index(name='count')

# Step 2: Map numeric values to descriptive labels
grouped['gender'] = grouped['gender'].map({1: 'Female', 2: 'Male'})
grouped['cholesterol'] = grouped['cholesterol'].map({
    1: 'Normal',
    2: 'Above Normal',
    3: 'Well Above Normal'
})
grouped['cardio'] = grouped['cardio'].map({0: 'No', 1: 'Yes'})

# Step 3: Plot using Seaborn
g = sns.catplot(
    data=grouped,
    x='cholesterol',
    y='count',
    hue='cardio',
    col='gender',
    kind='bar',
    height=5,
    aspect=1
)

# Step 4: Customize labels and titles
g.set_axis_labels("Cholesterol Level", "Count")
g.set_titles("Gender: {col_name}")
g._legend.set_title("Cardio Disease")
g.fig.suptitle("Cholesterol Level vs Cardio by Gender", y=1.05)

plt.show()

# %% [markdown]
# Insight Summary
#
# Higher cholesterol levels (2 & 3) are associated with more cardiovascular disease (Cardio = 1) cases in both genders.
#
# Cholesterol level 1 (normal) is most common and has more individuals without cardio issues (Cardio = 0).
#
# The trend is consistent across both males (Gender: 1) and females (Gender: 2), though males show a higher overall count.

# %%
sns.scatterplot(x='age', y='ap_hi',hue='cardio', data=df)
plt.title('Age vs Systolic Blood Pressure')
plt.show()

# %% [markdown]
# Insight Summary
#
# Systolic BP increases with age, especially for those with cardiovascular disease (Cardio = 1).
#
# Individuals with Cardio = 1 (orange dots) tend to have higher blood pressure than those without (blue).
#
# There are extreme outliers (e.g., BP > 10,000), which may be data entry errors and should be cleaned.

# %%
sns.scatterplot(x='age', y='ap_lo',hue='cardio', data=df)
plt.title('Age vs Diaotolic Blood Pressure')
plt.show()

# %% [markdown]
# Insight Summary
#
# Diastolic BP generally increases with age, especially among those with cardiovascular conditions (Cardio = 1).
#
# Individuals with Cardio = 1 (orange) tend to have higher diastolic pressure than those without (blue).
#
# Several extreme outliers (e.g., ap_lo > 6000) suggest data quality issues and should be cleaned before modeling.

# %%
sns.boxplot(x='cardio', y='weight', data=df)
# Out:
# <Axes: xlabel='cardio', ylabel='weight'>

# %% [markdown]
# Key Observations:
#
# Median Weight:
#
# People with cardio (1) tend to have a slightly higher median weight than those without cardio (0).
# Overall Distribution:
#
# The spread (IQR) is slightly wider for those with cardio, suggesting more variability in weight.
# The maximum and outliers are more or less comparable in both groups, but cardio-positive individuals appear to skew slightly heavier.
#
# Outliers:
#
# Both groups have a large number of high-weight outliers, especially beyond 100 kg.
#
# Insight:
#
# This supports the hypothesis that higher weight may be associated with cardiovascular disease, though
# we still need need statistical tests (e.g., t-test, Mann–Whitney U, or logistic regression) to quantify that relationship.

# %%
sns.boxplot(x='cardio', y='height', data=df)
# Out:
# <Axes: xlabel='cardio', ylabel='height'>

# %% [markdown]
# Key Observations:
# Median Height:
#
# People with cardio (1) tend to be slightly shorter on average than those without cardio.
# Height Range:
#
# The interquartile ranges (IQR) are quite similar.
# There are many outliers below 1.4m and a few above 2m, in both groups.
# Outliers:
#
# Some extreme values (below 1m or above 2.2m) may be data entry errors or rare cases.
# Health Insight:
#
# Height itself might not directly cause cardiovascular disease, but when combined with weight, it contributes to BMI (Body Mass Index), which is a known risk factor.

# %%
df['height_m'] = df['height']  # assuming height is already in meters
df['BMI'] = df['weight'] / (df['height_m'] ** 2)

# Visualize BMI vs cardio

plt.figure(figsize=(6, 5))
sns.boxplot(x='cardio', y='BMI', data=df)
plt.title('BMI Distribution by Cardiovascular Disease')
plt.show()

# %% [markdown]
# Interpretation of the BMI vs Cardio Box Plot
#
# 1. Median BMI
# Individuals with cardiovascular disease (cardio = 1) tend to have a higher median BMI than those without the disease.
# This suggests higher BMI is associated with increased cardiovascular risk.
#
# 2. Spread & Outliers
# Both groups have numerous outliers, especially extreme values well above the typical human BMI range (>100), which may indicate:
# Possible data entry errors
# Very rare cases (e.g., extreme obesity)
# Most values cluster between 20 and 40, aligning with real-world BMI ranges.
#
# 3. Interquartile Range (IQR)
# The IQR is slightly higher for cardio = 1, meaning people with cardio conditions tend to have a slightly wider spread in BMI values.
#
# Health Insight:
# BMI is a strong indicator for cardiovascular risk — as BMI increases, the risk of cardiovascular disease often increases due to associated conditions like hypertension, diabetes, and high cholesterol.

# %%
gender_map = {1: "Female", 2: "Male"}
labeled_barplot(df, "gender", perc=True, label_map=gender_map)

# %%
cholesterol_map = {
    1: "Normal",
    2: "Above Normal",
    3: "Well Above Normal"
}
labeled_barplot(df, "cholesterol", perc=True, label_map=cholesterol_map)

# %% [markdown]
# 74.8% of the people cholesterol level are in the normal range,13.6% of people cholesterol level are above normal while 11.5% of cholesterol level are well above normal

# %%
gluc_map = {
    1: "Normal",
    2: "Above Normal",
    3: "Well Above Normal"
}
labeled_barplot(df, "gluc", perc=True, label_map=gluc_map)

# %% [markdown]
# 85% of the people glucose level are in the normal range,7.4% of people glucose level are above normal while 7.6% of glucose level are well above normal

# %%
smoke_map = {
    0: "Non-Smoker",
    1: "Smoker"
}
labeled_barplot(df, "smoke", perc=True, label_map=smoke_map)

# %% [markdown]
# 91.2% of people do not smoke while 8.8% do

# %%
alco_map = {
    0: "Non-Drinker",
    1: "Drinker"
}
labeled_barplot(df, "alco", perc=True, label_map=alco_map)

# %% [markdown]
# 94.6% of people do not consume alcohol while the remaining 5.4% do

# %%
active_map = {
    0: "Inactive",
    1: "Active"
}
labeled_barplot(df, "active", perc=True, label_map=active_map)

# %% [markdown]
# 19.6% of people do not partake in physical activities while the remaining 80.4% does

# %%
cardio_map = {
    0: "No",
    1: "Yes"
}
labeled_barplot(df, "cardio", perc=True, label_map=cardio_map)

# %% [markdown]
# 50% of people have cardiovascular disease and vice versa

# %%
def histogram_boxplot(df, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=df, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=df, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=df, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        df[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        df[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
histogram_boxplot(df, "age", bins=25)
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_4260\1210359321.py:20: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Age Distribution Overview
# Box Plot (Top)
# Median Age: Approximately 53 years.
# Interquartile Range (IQR): Majority of the data falls between 48 and 58 years.
#
# Outliers: Two distinct young outliers below age 35, likely individuals under 30.
# Skewness: Slight left skew (longer tail on the lower age side), though the distribution remains fairly symmetric overall.
#
# Histogram (Bottom)
# Age Range: Spans from approximately 39 to 64 years.
# Most Common Age Group: Centered around 53 years, highlighted by the black dashed line (likely the median).
#
# Distribution Pattern: Displays a bimodal trend, with noticeable peaks between ages 50–60, and some dips in the middle range.
# Mean Age: Around 52.8 years, close to the median, confirming minimal skew.

# %% [markdown]
# Insights from Age Distribution
#
# Age Concentration: Most individuals are aged 48–58, indicating a middle-aged dominant group.
#
# Central Tendency: Mean (~52.8) and median (~53) are close, suggesting a fairly symmetric distribution.
#
# Outliers: Two young outliers (<35 years) may indicate rare cases or early-onset conditions.
#
# Skewness: Slight left skew, due to younger outliers.
#
# Bimodal Pattern: Two peaks suggest possible age-based subgroups (e.g., early 50s and late 50s).

# %%
histogram_boxplot(df, "weight", bins=25)
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_4260\1210359321.py:20: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Histogram:
# Displays the distribution of weights across the dataset.
#
# The green dashed line also appears to mark the mean.
#
# The data is right-skewed, meaning:
#
# Most people have a weight in the 60–80 kg range.
#
# But a few individuals have much higher weights (outliers).

# %%
histogram_boxplot(df, "height", bins=25)
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_4260\1210359321.py:20: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
histogram_boxplot(df, "ap_hi", bins=10)
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_15752\1210359321.py:20: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
histogram_boxplot(df, "ap_lo", bins=10)
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_15752\1210359321.py:20: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
corr_matrix = df.corr(numeric_only=True)
corr_matrix
plt.figure(figsize=(12,6))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# Key Insights
#
# BMI ↔ Weight: Strong positive correlation
#
# BMI ↔ Height: Strong negative correlation
#
# BMI ↔ Cardio: Moderate positive correlation — better predictor than weight/height alone
#
# ap_hi ↔ ap_lo: Strong positive correlation
#
# Age ↔ Cardio: Mild positive correlation
#
# Cholesterol & Gluc ↔ Cardio: Some correlation
#
# Lifestyle features (smoke, alco, active): Weak correlation with cardio
#
# Recommendations
# Use BMI instead of raw weight/height
#
# Create new features: pulse_pressure = ap_hi - ap_lo, age bins, BP categories
#
# Consider nonlinear models for better insight into weak correlations

# %%
df['age_group'] = pd.cut(df['age'], 
                         bins=[18, 30, 45, 60, 100], 
                         labels=['Young Adult', 'Adult', 'Middle-aged', 'Senior'], 
                         right=False)

# %%
df.groupby('age_group')['cardio'].mean()
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_7500\1542451985.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['cardio'].mean()
# age_group
# Young Adult    0.000000
# Adult          0.297595
# Middle-aged    0.496572
# Senior         0.670038
# Name: cardio, dtype: float64

# %%
df.groupby('age_group')['cardio'].mean().plot(kind='bar', title='Cardio by Age Group')
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_7500\968990012.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['cardio'].mean().plot(kind='bar', title='Cardio by Age Group')
# <Axes: title={'center': 'Cardio by Age Group'}, xlabel='age_group'>

# %% [markdown]
# Insights
# Young Adults have no cases of cardiovascular disease, which aligns with expectations — heart conditions
# are rarer at younger ages.
#
# The rate increases steadily with age.
#
# Seniors are the most affected, with over two-thirds (67%) having cardiovascular disease.
#
# Middle-aged individuals already show a high rate (about 50%), indicating this group is a key target for early prevention efforts.
#
# Recommendation
#
# Target preventive care and awareness campaigns at adults and middle-aged individuals, before they transition into the higher-risk senior category.

# %%
df.groupby('age_group')['smoke'].mean()
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_7500\1389634643.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['smoke'].mean()
# age_group
# Young Adult    0.000000
# Adult          0.110332
# Middle-aged    0.087836
# Senior         0.071724
# Name: smoke, dtype: float64

# %%
df.groupby('age_group')['smoke'].mean().plot(kind='bar', title='Smoke by Age Group')
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_7500\4177463696.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['smoke'].mean().plot(kind='bar', title='Smoke by Age Group')
# <Axes: title={'center': 'Smoke by Age Group'}, xlabel='age_group'>

# %% [markdown]
# Insights
# Young Adults don’t smoke at all in this dataset — possibly due to awareness, regulation, or sample size.
#
# Adults have the highest smoking rate, potentially reflecting lifestyle habits formed in early adulthood.
#
# Smoking decreases with age, either due to quitting for health reasons or survival bias (smokers may not make it to older age).
#
# Despite the drop in smoking among seniors, they still show the highest rate of cardiovascular disease, suggesting that age is a stronger factor than smoking alone — though both matter.

# %%
df.groupby('age_group')['alco'].mean().plot(kind='bar', title='Alcohol by Age Group')
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_7500\3223139970.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['alco'].mean().plot(kind='bar', title='Alcohol by Age Group')
# <Axes: title={'center': 'Alcohol by Age Group'}, xlabel='age_group'>

# %% [markdown]
# Insights from the Chart:
#
# Young Adults: 0% — no alcohol consumption reported.
#
# Adults: Highest alcohol consumption rate (~6.3%).
#
# Middle-aged: Slightly lower than adults (~5.5%).
#
# Seniors: Lowest among consumers (~4.3%).
#
# Interpretation:
#
# Alcohol consumption seems to peak in adulthood, then gradually declines with age.
#
# Young adults don’t consume alcohol at all in this dataset — this could be due to age restrictions, sample size, or social/health reasons.
#
# As people age (from middle-aged to senior), alcohol consumption declines, possibly due to health consciousness or medical advice.

# %%
df.groupby('age_group')['BMI'].mean().plot(kind='bar', title='BMI')
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_7500\2601335925.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['BMI'].mean().plot(kind='bar', title='BMI')
# <Axes: title={'center': 'BMI'}, xlabel='age_group'>

# %% [markdown]
# Key Observations:
#
# Young Adults have the lowest BMI (~24.5), which is in the normal range.
#
# Adults and Middle-aged individuals show higher BMIs (~27–28), leaning toward the overweight category.
#
# Seniors have the highest average BMI (~28.5), maintaining the trend of increasing BMI with age.
#
# Interpretation:
#
# BMI increases with age, possibly due to:
#
# Reduced physical activity
#
# Slower metabolism
#
# Lifestyle and dietary habits over time
#
# This chart complements the earlier Alcohol Consumption by Age Group chart — while alcohol use declines
#
# with age, BMI increases, indicating a potential shift in health risk factors as people grow older.

# %%
df.groupby('age_group')['cholesterol'].value_counts(normalize=True).unstack()
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_7500\436705537.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['cholesterol'].value_counts(normalize=True).unstack()
# cholesterol         1         2         3
# age_group
# Young Adult  1.000000  0.000000  0.000000
# Adult        0.839030  0.117830  0.043140
# Middle-aged  0.749068  0.139016  0.111916
# Senior       0.674406  0.141762  0.183831

# %% [markdown]
# Interpretation:
# Young Adults have exclusively normal cholesterol.
#
# As age increases, the proportion of high cholesterol (level 3) rises significantly:
# Adults: 4.3%
# Middle-aged: 11.2%
# Seniors: 18.4%
#
# Insights:
#
# Age is a strong factor in elevated cholesterol levels.
#
# This aligns with typical health risks — older adults are more likely to develop high cholesterol, potentially due to:
#
# Diet
# Physical inactivity
# Genetics
# Cumulative health factors over time

# %%
df.groupby('age_group')['gluc'].value_counts(normalize=True).unstack()
# Out:
# C:\Users\Habeeb\AppData\Local\Temp\ipykernel_7500\2045740378.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['gluc'].value_counts(normalize=True).unstack()
# gluc                1         2         3
# age_group
# Young Adult  1.000000  0.000000  0.000000
# Adult        0.900088  0.062810  0.037102
# Middle-aged  0.849929  0.073846  0.076224
# Senior       0.809195  0.084138  0.106667

# %% [markdown]
# Gluc 1, 2, 3 represent categories of glucose levels, typically:
#
# 1 = Normal glucose
#
# 2 = Above normal glucose
#
# 3 = High glucose (possible diabetes or pre-diabetes level)
#
# The numbers in the table represent the proportion of people in each age group that fall into each gluc category. For example:
#
# Among Young Adults, 100% have normal glucose (gluc=1), 0% have levels 2 or 3.
#
# Among Adults, ~90% have normal glucose, ~6.3% have level 2, and ~3.7% have level 3.
#
# Among Middle-aged, normal glucose drops to ~85%, with about 7.4% and 7.6% in levels 2 and 3 respectively.
#
# Among Seniors, only ~81% have normal glucose, while 8.4% have level 2, and 10.7% have level 3.
#
# What does this mean?
# As age increases, the proportion of people with normal glucose (gluc=1) decreases.
#
# Conversely, the proportion of people with elevated glucose levels (gluc=2 and gluc=3) increases with age.
#
# This suggests older age groups tend to have higher blood glucose levels, which might indicate a higher risk of diabetes or glucose intolerance as age advances.
#
# Summary
# Younger people (Young Adults) almost exclusively have normal glucose.
#
# The prevalence of elevated and high glucose levels rises gradually with age groups Adult → Middle-aged → Senior.
#
# This pattern aligns with general medical knowledge that risk for glucose abnormalities (and diabetes) increases with age.

# %%
sns.pairplot(data, hue="cardio")
plt.show()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Removing Outliers

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900     52.840671      1.349571      1.643592     74.205690
# std    28851.302323      6.766774      0.476838      0.082101     14.395757
# min        0.000000     29.000000      1.000000      0.550000     10.000000
# 25%    25006.750000     48.000000      1.000000      1.590000     65.000000
# 50%    50001.500000     53.000000      1.000000      1.650000     72.000000
# 75%    74889.250000     58.000000      2.000000      1.700000     82.000000
# max    99999.000000     64.000000      2.000000      2.500000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
#Removing outliers for weight and height
Q1 = df[['weight', 'height']].quantile(0.25)
Q3 = df[['weight', 'height']].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df[['weight', 'height']] < (Q1 - 1.5 * IQR)) |(df[['weight', 'height']] > (Q3 + 1.5 * IQR))).any(axis=1)]#+

# %%
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)
IQR = Q3 - Q1

# Keep only rows **within** the IQR range
df = df[(df['BMI'] >= (Q1 - 1.5 * IQR)) & (df['BMI'] <= (Q3 + 1.5 * IQR))]

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2    1.68    62.0    110     80            1     1
# 1          1   55       1    1.56    85.0    140     90            3     1
# 2          2   51       1    1.65    64.0    130     70            3     1
# 3          3   48       2    1.69    82.0    150    100            1     1
# 4          4   47       1    1.56    56.0    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69994  99992   57       1    1.65    80.0    150     80            1     1
# 69995  99993   52       2    1.68    76.0    120     80            1     1
# 69997  99996   52       2    1.83   105.0    180     90            3     1
# 69998  99998   61       1    1.63    72.0    135     80            1     2
# 69999  99999   56       1    1.70    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  height_m        BMI    age_group
# ...

# %%
#In some cases diastolic pressure is higher than systolic,which is also incorrect. How many records are incorrect in terms of blood pressure?
print("Diastilic pressure is higher than systolic one in {0} cases".format(df[df["ap_lo"]>df["ap_hi"]].shape[0]))
# Out:
# Diastilic pressure is higher than systolic one in 1160 cases

# %%
# Removing outliers for ap_hi and ap_lo#
# Calculate Q1 and Q3
Q1 = df[['ap_hi', 'ap_lo']].quantile(0.25)
Q3 = df[['ap_hi', 'ap_lo']].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Remove outliers based on IQR
df = df[~((df[['ap_hi', 'ap_lo']] < (Q1 - 1.5 * IQR)) |
          (df[['ap_hi', 'ap_lo']] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2    1.68    62.0    110     80            1     1
# 1          1   55       1    1.56    85.0    140     90            3     1
# 2          2   51       1    1.65    64.0    130     70            3     1
# 3          3   48       2    1.69    82.0    150    100            1     1
# 5          8   60       1    1.51    67.0    120     80            2     2
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69993  99991   53       1    1.72    70.0    130     90            1     1
# 69994  99992   57       1    1.65    80.0    150     80            1     1
# 69995  99993   52       2    1.68    76.0    120     80            1     1
# 69998  99998   61       1    1.63    72.0    135     80            1     2
# 69999  99999   56       1    1.70    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  height_m        BMI    age_group
# ...

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  62748.000000  62748.000000  62748.000000  62748.000000  62748.000000
# mean   49951.571699     52.881287      1.357876      1.646654     73.265555
# std    28864.966432      6.748137      0.479379      0.077757     12.633516
# min        0.000000     29.000000      1.000000      1.200000     28.000000
# 25%    24892.500000     48.000000      1.000000      1.590000     65.000000
# 50%    49978.500000     54.000000      1.000000      1.650000     72.000000
# 75%    74876.250000     58.000000      2.000000      1.700000     81.000000
# max    99999.000000     64.000000      2.000000      2.070000    135.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  62748.000000  62748.000000  62748.000000  62748.000000  62748.000000
# mean     126.403854     81.689297      1.356872      1.220931      0.088624
# ...

# %%
age_mapping = {
    'Young Adult': 1,
    'Adult': 2,
    'Middle-aged': 3,
    'Senior': 4
}

df['age_group_encoded'] = df['age_group'].map(age_mapping)

# %%
#standard scaling for age,height,weight,ap_hi,ap_lo
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['age','BMI', 'ap_hi', 'ap_lo']] = scaler.fit_transform(df[['age','BMI', 'ap_hi', 'ap_lo']])

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  62748.000000  6.274800e+04  62748.000000  62748.000000  62748.000000
# mean   49951.571699 -5.415018e-16      1.357876      1.646654     73.265555
# std    28864.966432  1.000008e+00      0.479379      0.077757     12.633516
# min        0.000000 -3.538973e+00      1.000000      1.200000     28.000000
# 25%    24892.500000 -7.233590e-01      1.000000      1.590000     65.000000
# 50%    49978.500000  1.657823e-01      1.000000      1.650000     72.000000
# 75%    74876.250000  7.585432e-01      2.000000      1.700000     81.000000
# max    99999.000000  1.647684e+00      2.000000      2.070000    135.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  6.274800e+04  6.274800e+04  62748.000000  62748.000000  62748.000000
# mean   6.499833e-17  2.457254e-16      1.356872      1.220931      0.088624
# ...

# %%
# Unnecessary features would decrease the training speed, the model interpretability and the generalization performance on the test data. 
# Therefore, finding and selecting the most useful features in the dataset is crucial.
# Assigning input features to X and output (Churn) to y

X = df.drop(["age","id","cardio","height","weight","height_m","age_group","smoke","alco"], axis = "columns") 
y = df["cardio"]

# %%
X.shape
# Out:
# (61345, 8)

# %%
y.shape
# Out:
# (61345,)

# %%
# Perform train/test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 120)

# %%
X_train.shape
# Out:
# (42941, 8)

# %%
X_test.shape
# Out:
# (18404, 8)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

model_LRR = LogisticRegression()
        
model_LRR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predict = model_LRR.predict(X_test)

# %%
print(classification_report(y_test, y_predict))
# precision is the ratio of TP/(TP+FP)
# recall is the ratio of TP/(TP+FN)
# F-beta score can be interpreted as a weighted harmonic mean of the precision and recall
# where an F-beta score reaches its best value at 1 and worst score at 0.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75      9367
#            1       0.75      0.66      0.70      9037
#
#     accuracy                           0.73     18404
#    macro avg       0.73      0.72      0.72     18404
# weighted avg       0.73      0.73      0.72     18404

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
train_accuracy = model_LRR.score(X_train, y_train)
test_accuracy = model_LRR.score(X_test, y_test)

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Train Accuracy: 0.7234
# Test Accuracy: 0.7259

# %% [markdown]
# # CODING TASK : TRAIN AND EVALUATE A SUPPORT VECTOR MACHINE CLASSIFIER

# %%
from sklearn.calibration import CalibratedClassifierCV # For probability score output
from sklearn.svm import LinearSVC

model_svc = LinearSVC(max_iter=100000)
model_svm = CalibratedClassifierCV(model_svc) 
model_svm.fit(X_train, y_train)
# Out:
# C:\Users\Habeeb\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\Habeeb\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\Habeeb\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# ...

# %%
y_predictSV = model_svm.predict(X_test)

# %%
print(classification_report(y_test, y_predictSV))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.74      9367
#            1       0.75      0.66      0.70      9037
#
#     accuracy                           0.73     18404
#    macro avg       0.73      0.72      0.72     18404
# weighted avg       0.73      0.73      0.72     18404

# %%
cm = confusion_matrix(y_test, y_predictSV)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# # CODING TASK : TRAIN AND EVALUATE A NAIVE BAYES CLASSIFIER

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_gnb = GaussianNB()
model_gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_predictNB = model_gnb.predict(X_test)

# %%
print(classification_report(y_test, y_predictNB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.81      0.74      9367
#            1       0.76      0.60      0.67      9037
#
#     accuracy                           0.71     18404
#    macro avg       0.72      0.71      0.71     18404
# weighted avg       0.72      0.71      0.71     18404

# %%
cm = confusion_matrix(y_test, y_predictNB)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# # CODING TASK : TRAIN AND EVALUATE A RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier()
model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predictRF = model_rf.predict(X_test)

# %%
print(classification_report(y_test, y_predictRF))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.69      0.68      9367
#            1       0.66      0.63      0.65      9037
#
#     accuracy                           0.66     18404
#    macro avg       0.66      0.66      0.66     18404
# weighted avg       0.66      0.66      0.66     18404

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(
    n_estimators=50,         # Fewer trees (you can try 30 too)
    max_depth=10,            # Prevent very deep trees
    min_samples_split=10,    # Require more samples to split
    min_samples_leaf=4,      # Avoid tiny leaf nodes
    class_weight='balanced', # Balance class influence
    random_state=42
)

random_forest.fit(X_train, y_train)

# Evaluate
train_acc = random_forest.score(X_train, y_train)
test_acc = random_forest.score(X_test, y_test)

print(f"Training Accuracy: {round(train_acc * 100, 2)}%")
print(f"Test Accuracy: {round(test_acc * 100, 2)}%")

# Prediction and evaluation
y_pred = random_forest.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training Accuracy: 73.84%
# Test Accuracy: 72.96%
# [[7434 1933]
#  [3043 5994]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75      9367
#            1       0.76      0.66      0.71      9037
#
#     accuracy                           0.73     18404
#    macro avg       0.73      0.73      0.73     18404
# weighted avg       0.73      0.73      0.73     18404

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# # CODING TASK : TRAIN AND EVALUATE A KNN CLASSIFIER

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier()
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predictKN = model_knn.predict(X_test)

# %%
print(classification_report(y_test, y_predictKN))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70      9367
#            1       0.69      0.66      0.68      9037
#
#     accuracy                           0.69     18404
#    macro avg       0.69      0.69      0.69     18404
# weighted avg       0.69      0.69      0.69     18404

# %%
cm = confusion_matrix(y_test, y_predictKN)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %% [markdown]
# # ROC_AUC CURVE

# %%
# ROC curve
from sklearn.metrics import roc_curve

fpr0, tpr0, thresh0 = roc_curve(y_test, model_LRR.predict_proba(X_test)[:, 1], pos_label = 1)
fpr1, tpr1, thresh1 = roc_curve(y_test, model_svm.predict_proba(X_test)[:, 1], pos_label = 1)
fpr2, tpr2, thresh2 = roc_curve(y_test, model_gnb.predict_proba(X_test)[:, 1], pos_label = 1)
fpr3, tpr3, thresh3 = roc_curve(y_test, random_forest.predict_proba(X_test)[:, 1], pos_label = 1)
fpr4, tpr4, thresh4 = roc_curve(y_test, model_knn.predict_proba(X_test)[:, 1], pos_label = 1)

# %%
# AUC score

from sklearn.metrics import roc_auc_score

auc_score0 = roc_auc_score(y_test, model_LRR.predict_proba(X_test)[:, 1])
auc_score1 = roc_auc_score(y_test, model_svm.predict_proba(X_test)[:, 1])
auc_score2 = roc_auc_score(y_test, model_gnb.predict_proba(X_test)[:, 1])
auc_score3 = roc_auc_score(y_test, random_forest.predict_proba(X_test)[:, 1])
auc_score4 = roc_auc_score(y_test, model_knn.predict_proba(X_test)[:, 1])

print("Logistic Regression: ", auc_score0) # Logistic Regression
print("Support Vector Machine: ", auc_score1) # Support Vector Machine
print("Naive Bayes: ", auc_score2) # Support Vector Machine
print("Random Forest: ", auc_score3) # Random Forest
print("K-Nearest Neighbors: ", auc_score4) # K-Nearest Neighbors
# Out:
# Logistic Regression:  0.7837238800679682
# Support Vector Machine:  0.7837299403461889
# Naive Bayes:  0.7711500195411486
# Random Forest:  0.7893780074204504
# K-Nearest Neighbors:  0.7345185083554875

# %%
plt.plot(fpr0, tpr0, linestyle = "--", color = "blue", label = "Logistic Regression")
plt.plot(fpr1, tpr1, linestyle = "--", color = "orange", label = "SVM")
plt.plot(fpr2, tpr2, linestyle = "--", color = "red", label = "Naive Bayes")
plt.plot(fpr3, tpr3, linestyle = "--", color = "green", label = "Random Forest")
plt.plot(fpr4, tpr4, linestyle = "--", color = "yellow", label = "KNN")


plt.title('Receiver Operator Characteristics (ROC)')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')

plt.legend(loc = 'best')
plt.savefig('ROC', dpi = 300)
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

models = {
    "Logistic Regression": model_LRR,
    "SVM": model_svm,
    "Naive Bayes": model_gnb,
    "Random Forest": random_forest,
    "KNN": model_knn
}

# To store results
results = []

# Loop through each model
for name, model in models.items():
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append([name, round(acc, 2), round(prec, 2), round(rec, 2), round(f1, 2)])

# Display neatly
import pandas as pd

results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "Precision", "Recall", "F1-Score"])
print(results_df.sort_values(by="F1-Score", ascending=False).reset_index(drop=True))
# Out:
#                  Model  Accuracy  Precision  Recall  F1-Score
# 0        Random Forest      0.73       0.76    0.66      0.71
# 1  Logistic Regression      0.73       0.75    0.66      0.70
# 2                  SVM      0.73       0.75    0.66      0.70
# 3                  KNN      0.69       0.69    0.66      0.68
# 4          Naive Bayes      0.71       0.76    0.60      0.67

# %%
# Plot F1 Scores
results_df.plot(x='Model', y=['Accuracy', 'Precision', 'Recall', 'F1-Score'], kind='bar', figsize=(10,6))
plt.title('Model Performance Comparison')
plt.ylabel('Score')
plt.ylim(0.6, 0.8)
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(loc='lower right')
plt.tight_layout()

# %%
import pandas as pd

# New data for prediction (ensure all features used in training are present)
new_data = pd.DataFrame({
    'age': [15000],           # Age in days
    'height': [165],          # Height in cm
    'weight': [70],           # Weight in kg
    'ap_hi': [120],           # Systolic blood pressure
    'ap_lo': [80],            # Diastolic blood pressure
    'active': [1],            # Physical activity: 1 for active
    'BMI': [25.7],            # Body Mass Index (if computed and used)
    'cholesterol': [1],       # 1: normal, 2: above normal, 3: well above normal
    'gluc': [1]            # Same encoding as cholesterol
})


new_data = new_data[X.columns]  

prediction = random_forest.predict(new_data)
probabilities = random_forest.predict_proba(new_data)


print("Predicted class (0 = no cardio disease, 1 = has cardio disease):", prediction[0])
print("Prediction probabilities [P(no disease), P(disease)]:", probabilities[0])
